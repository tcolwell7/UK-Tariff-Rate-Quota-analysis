# %% [markdown]
# ### UK TRQ Quality Assurance Notebook.

# %% [markdown]
# #### The following notebook is a qualtiy assurance script for the UK TRQ analysis.

# %% [markdown]
# The note book is split into the following parts:
#
# **TRQ data:**
#
# 1. Data cleaning
# 2. Aggregate data and calculate utilisation rates
# 3. Compare outputs
#
# **TRQ sector data:**
#
#
# **Filled quotas:**

# %% [markdown]
# ****

# %% [markdown]
# ### **Part 1: data cleaning:**

# %% [markdown]
# Data uploads and clean column strings:

# %%
# upload data:

import pandas as pd
import numpy as np

# !pip install openpyxl

# chnage from scientific notation 
pd.set_option('display.float_format', lambda x: '%.5f' % x)

uk_trqs = pd.read_excel('../rsp_uk_trq_qa/data/uk_trq_data.xlsx',dtype={'Quota Number': str}) 
uk_trqs2 = pd.read_excel('../rsp_uk_trq_qa/data/uk_license_trq_input.xlsx',dtype={'Quota number': str}) 
eu_trqs = pd.read_excel('../rsp_uk_trq_qa/data/eu_trq_data.xlsx',dtype={'Order_Number': str}) 


print(uk_trqs.shape, uk_trqs2.shape, eu_trqs.shape)
# Out:
# Looking in indexes: https://s3-eu-west-2.amazonaws.com/mirrors.notebook.uktrade.io/pypi/
# Collecting openpyxl
#   Downloading https://s3-eu-west-2.amazonaws.com/mirrors.notebook.uktrade.io/pypi/openpyxl/openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.2/242.2 KB 183.6 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading https://s3-eu-west-2.amazonaws.com/mirrors.notebook.uktrade.io/pypi/et-xmlfile/et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.9
# WARNING: You are using pip version 22.0.4; however, version 22.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python3 -m pip install --upgrade pip' command.
# (1067, 14) (95, 17) (12445, 26)

# %%
# upload input files

uk_trq_country_input = pd.read_excel('../rsp_uk_trq_qa/data/uk_trq_country_input.xlsx')
hs_dsc = pd.read_excel('../rsp_uk_trq_qa/data/hs_descriptions.xlsx')
country_names = pd.read_excel('../rsp_uk_trq_qa/data/country_names.xlsx')
eu_trq_data_input = pd.read_excel('../rsp_uk_trq_qa/data/eu_trq_data_input.xlsx')
eu_trq_sector_manual_input = pd.read_excel('../rsp_uk_trq_qa/data/eu_trq_sector_manual_input.xlsx')
trq_quota_unit = pd.read_excel('../rsp_uk_trq_qa/data/trq_quota_unit.xlsx')

print(uk_trq_country_input.shape, hs_dsc.shape, country_names.shape, eu_trq_data_input.shape, eu_trq_sector_manual_input.shape,trq_quota_unit.shape)
# Out:
# (70, 4) (98, 3) (225, 4) (114, 4) (249, 11) (6, 3)

# %%
def  cleanCols(df): 
    df.columns = df.columns.str.lower().str.replace(" ","_")
    return(df)

# %%
# clean names of dataframes:

uk_trqs = cleanCols(uk_trqs)
uk_trqs2 = cleanCols(uk_trqs2)
eu_trqs = cleanCols(eu_trqs)
uk_trq_country_input = cleanCols(uk_trq_country_input)
hs_dsc = cleanCols(uk_trq_country_input)
country_names = cleanCols(country_names)
eu_trq_data_input = cleanCols(eu_trq_data_input)
eu_trq_sector_manual_input = cleanCols(eu_trq_sector_manual_input)
trq_quota_unit = cleanCols(trq_quota_unit)

# %%
# clean and combine UK TRQ data:
print(uk_trqs.dtypes)
# Out:
# quota_number                  object
# quota_product_description     object
# year                           int64
# quota_origin                  object
# validity_start_date           object
# validity_end_date             object
# quota_volume                 float64
# remaining_balance            float64
# quota_fill_rate              float64
# quota_unit                    object
# commodity_codes               object
# quota_status                  object
# last_allocation_date          object
# trq_type                      object
# dtype: object

# %%
# select data for non-license quotas:

uk = uk_trqs.loc[:,["quota_number",
                   "quota_product_description",
                 "year",
                 "quota_origin",
                 "quota_volume",
                 "remaining_balance",
                 "quota_unit",
                 "commodity_codes"]
                ]

# rename

uk.rename(columns = {'quota_product_description':'quota_description', 'year':'quota_year'}, inplace = True)
uk.head()

# filter for quota year = 2021

uk = uk.loc[uk["quota_year"] == 2021]

# match country/region names for combining with license data and final aggregated outputs:

uk = pd.merge(uk, uk_trq_country_input, left_on = "quota_origin", right_on = "country_name", how = "left")

# filter away NA (i.e. non match)

uk = uk[uk['region'].notnull()]

uknan = uk[uk['region'].isnull()] # NaN df for reference. 

uk.head()
# Out:
#    quota_number                                quota_description  quota_year  \
# 67       050146                              Live bovine animals        2021
# 72       050155  Meat and edible offal, of duch, fresh or forzen        2021
# 78       050202      Potatoes, fresh or chilled, other than seed        2021
# 79       050204                               Fresh table grapes        2021
# 80       050204                               Fresh table grapes        2021
#
#    quota_origin  quota_volume  remaining_balance              quota_unit  \
# 67  Switzerland     247.00000          247.00000  Number of items (p/st)
# 72       Israel   76000.00000        76000.00000           Kilogram (kg)
# 78       Turkey  417000.00000       322220.00000           Kilogram (kg)
# 79       Turkey   58000.00000        58000.00000           Kilogram (kg)
# 80       Turkey   58000.00000            0.00000           Kilogram (kg)
#
#                                       commodity_codes iso country_name  \
# 67  0102294100 ; 0102294900 ; 0102295100 ; 0102295...  CH  Switzerland
# 72  0207423000 ; 0207428000 ; 0207441000 ; 0207442...  IL       Israel
# 78                                         0701900000  TR       Turkey
# 79                                         0806101090  TR       Turkey
# 80                                         0806101090  TR       Turkey
#
#        grouping                      region
# 67  Switzerland  Wider Europe & Middle East
# 72       Israel  Wider Europe & Middle East
# 78       Turkey              Eastern Europe
# 79       Turkey              Eastern Europe
# 80       Turkey              Eastern Europe

# %%
# convert quota unit measurments for consistency i.e. Tonnes to be in Kilograms, HectoLitres to be in Litres etc. 
# convert Tonnes to Kilograms. 
print(pd.unique(uk["quota_unit"]))
# Out:
# ['Number of items (p/st)' 'Kilogram (kg)' 'Litre (l)' 'Hectolitre (hl)'
#  'Tonne (1,000 kg)' 'Square metre (m2)' 'Number of pairs (pa)'
#  'Litre pure (100%) alcohol (l alc. 100%)']

# %%
uk["tonne_flag"] = np.where(uk["quota_unit"].str.contains("Tonne"), True,False)
uk["quota_unit"] = np.where(uk["tonne_flag"] == True, "Kilogram (kg)", uk["quota_unit"])

# %%
uk["quota_volume"] = np.where(uk["tonne_flag"] == True,uk["quota_volume"]*1000,uk["quota_volume"])
uk["remaining_balance"] = np.where(uk["tonne_flag"] == True,uk["remaining_balance"]*1000,uk["remaining_balance"])

# %%
# convert HL to L:
uk["hl_flag"] = np.where(uk["quota_unit"].str.contains("Hecto"), True,False)
uk["quota_unit"] = np.where(uk["hl_flag"] == True, "Litre (l)", uk["quota_unit"])
uk["quota_volume"] = np.where(uk["hl_flag"] == True,uk["quota_volume"]*100,uk["quota_volume"])
uk["remaining_balance"] = np.where(uk["hl_flag"] == True,uk["remaining_balance"]*100,uk["remaining_balance"])

# %%
# match final quota unit df. This is to combine a common name across the EU and UK data to combine and aggregate. 

uk = pd.merge(uk, trq_quota_unit[["uk_quota_unit","quota_unit_final"]], left_on = "quota_unit", right_on = "uk_quota_unit", how = "left")
uk.head()
# Out:
#   quota_number                                quota_description  quota_year  \
# 0       050146                              Live bovine animals        2021
# 1       050155  Meat and edible offal, of duch, fresh or forzen        2021
# 2       050202      Potatoes, fresh or chilled, other than seed        2021
# 3       050204                               Fresh table grapes        2021
# 4       050204                               Fresh table grapes        2021
#
#   quota_origin  quota_volume  remaining_balance              quota_unit  \
# 0  Switzerland     247.00000          247.00000  Number of items (p/st)
# 1       Israel   76000.00000        76000.00000           Kilogram (kg)
# 2       Turkey  417000.00000       322220.00000           Kilogram (kg)
# 3       Turkey   58000.00000        58000.00000           Kilogram (kg)
# 4       Turkey   58000.00000            0.00000           Kilogram (kg)
#
#                                      commodity_codes iso country_name  \
# 0  0102294100 ; 0102294900 ; 0102295100 ; 0102295...  CH  Switzerland
# 1  0207423000 ; 0207428000 ; 0207441000 ; 0207442...  IL       Israel
# 2                                         0701900000  TR       Turkey
# 3                                         0806101090  TR       Turkey
# 4                                         0806101090  TR       Turkey
#
#       grouping                      region  tonne_flag  hl_flag  \
# 0  Switzerland  Wider Europe & Middle East       False    False
# 1       Israel  Wider Europe & Middle East       False    False
# 2       Turkey              Eastern Europe       False    False
# 3       Turkey              Eastern Europe       False    False
# 4       Turkey              Eastern Europe       False    False
#
#             uk_quota_unit quota_unit_final
# 0  Number of items (p/st)  Number of items
# 1           Kilogram (kg)        Kilograms
# 2           Kilogram (kg)        Kilograms
# 3           Kilogram (kg)        Kilograms
# 4           Kilogram (kg)        Kilograms

# %%
# remove columns:
uk = uk.drop(["tonne_flag","hl_flag","uk_quota_unit"], 1)
#uk.dtypes

# %%
# filter licnese quota data

uk2 = uk_trqs2.loc[uk_trqs2["year"] == 2021]
uk2.shape
# Out:
# (95, 17)

# %%
uk2 = uk2[uk2["rsp_region"].notnull()]
uk2.dtypes
# Out:
# quota_number                object
# quota_description           object
# year                         int64
# quota_origin                object
# rsp_region                  object
# quota_period                object
# quota_unit                  object
# commodity_codes             object
# trq_type                    object
# 2021_quantity_available      int64
# 2021_quantity_remaining    float64
# 2021_usage                 float64
# 2021_fill_rate             float64
# unnamed:_13                float64
# unnamed:_14                float64
# unnamed:_15                float64
# unnamed:_16                float64
# dtype: object

# %%
# match country input file for consitent naming across dfs
uk2 = pd.merge(uk2, uk_trq_country_input, left_on = "quota_origin", right_on = "country_name", how = "left")
uk2.dtypes
# Out:
# quota_number                object
# quota_description           object
# year                         int64
# quota_origin                object
# rsp_region                  object
# quota_period                object
# quota_unit                  object
# commodity_codes             object
# trq_type                    object
# 2021_quantity_available      int64
# 2021_quantity_remaining    float64
# 2021_usage                 float64
# 2021_fill_rate             float64
# unnamed:_13                float64
# unnamed:_14                float64
# unnamed:_15                float64
# unnamed:_16                float64
# iso                         object
# country_name                object
# grouping                    object
# region                      object
# dtype: object

# %%
# join quota unit input for consistent quota unit names across dfs
uk2 = pd.merge(uk2, trq_quota_unit[["uk_quota_unit","quota_unit_final"]], left_on = "quota_unit", right_on = "uk_quota_unit", how = "left")

# %%
uk2.dtypes
# Out:
# quota_number                object
# quota_description           object
# year                         int64
# quota_origin                object
# rsp_region                  object
# quota_period                object
# quota_unit                  object
# commodity_codes             object
# trq_type                    object
# 2021_quantity_available      int64
# 2021_quantity_remaining    float64
# 2021_usage                 float64
# 2021_fill_rate             float64
# unnamed:_13                float64
# unnamed:_14                float64
# unnamed:_15                float64
# unnamed:_16                float64
# iso                         object
# country_name                object
# grouping                    object
# region                      object
# uk_quota_unit               object
# quota_unit_final            object
# dtype: object

# %%
uk2 = uk2.loc[:,["quota_number",
                "quota_description",
                 "year",
                 "quota_origin",
                 "2021_quantity_available",
                 "2021_quantity_remaining",
                 "quota_unit",
                 "commodity_codes",
                     "iso",
                     "country_name",
                     "grouping",
                     "region",
                     "quota_unit_final"]
                ]

uk2.rename(columns = {"2021_quantity_available":"quota_volume","2021_quantity_remaining":"remaining_balance", 'year':'quota_year'}, inplace = True)

# %%
# combine uk dfs together

uk3 = pd.concat([uk,uk2])
uk3.shape
# Out:
# (810, 13)

# %%
# eu data - match country input for consistent grouping/region names and filter

eu = eu_trqs.loc[eu_trqs["year"] == 2020]

eu = pd.merge(eu, eu_trq_data_input, on = "origin", how = "left")

eu = eu[eu["region"].notnull()] # filter Non region match

# rename order number:

eu.rename(columns = {'order_number':'quota_number', 'year':'quota_year'}, inplace = True)

# %%
# match quota unit for consistency across dfs
eu = pd.merge(eu, trq_quota_unit[["eu_quota_unit","quota_unit_final"]], left_on = "unit", right_on = "eu_quota_unit", how = "left")

# %%
eu.dtypes
# Out:
# quota_number                         object
# origin                               object
# description                          object
# quota_year                            int64
# application_period_starts    datetime64[ns]
# application_period_ends      datetime64[ns]
# volume                              float64
# eu_usage                            float64
# unit                                 object
# last_import_date             datetime64[ns]
# report_date                  datetime64[ns]
# live                                float64
# adj_ap_start                 datetime64[ns]
# adj_ap_end                   datetime64[ns]
# source                               object
# cn8_codes                            object
# cn10_codes                           object
# inquota_rate                         object
# regulations                          object
# quota_type                           object
# eu_usage_source                      object
# origin_code_x                        object
# country_exc                          object
# trq_category                         object
# trqperiod                            object
# trq_period                           object
# origin_code_y                        object
# grouping                             object
# region                               object
# eu_quota_unit                        object
# quota_unit_final                     object
# dtype: object

# %%
eu_trq_data_input
# Out:
#                              origin  \
# 0                               ACP
# 1                     ACP-Cariforum
# 2                           Albania
# 3                           Algeria
# 4                         Argentina
# ..                              ...
# 109                   WTO countries
# 110  XK, MK, RS, ME, XW, AL, HR, BA
# 111              XK, XV, RS, ME, BA
# 112                        XN, 2300
# 113                        XN, 2301
#
#                                            origin_code  \
# 0    AO, AG, BB, BZ, BJ, BW, BF, BI, CM, CV, CF, TD...
# 1    AO, AG, BB, BZ, BJ, BW, BF, BI, CM, CV, CF, TD...
# 2                                                   AL
# 3                                                   DZ
# 4                                                   AR
# ..                                                 ...
# 109                                               E.O.
# 110                     XK, MK, RS, ME, XW, AL, HR, BA
# 111                                 XK, XV, RS, ME, BA
# 112     AR, BD, BR, SV, GT, HN, IN, ID, LA, PK, LK, TH
# 113  AR, BD, BO, BR, CL, EC, SV, GT, HN, IN, ID, IR...
#
#                            grouping          region
# 0                               ACP             NaN
# 1                     ACP-Cariforum             NaN
# 2                           Albania  Eastern Europe
# 3                           Algeria             NaN
# 4                         Argentina             NaN
# ..                              ...             ...
# 109                      ERGA OMNES             NaN
# 110  XK, MK, RS, ME, XW, AL, HR, BA             NaN
# 111              XK, XV, RS, ME, BA             NaN
# 112                        XN, 2300             NaN
# 113                        XN, 2301             NaN
#
# [114 rows x 4 columns]

# %% [markdown]
# ### **2. Data aggregations and utilisation calculations**

# %% [markdown]
# Both UK and EU data need to be grouped by quota origin, grouping and region to produce 3 seperate outputs.
#
# Grouping is combined with quota unit as TRQs need to be outputted broken down by quota unit as they can't be mixed together (i.e. KG with Litre) as they highlight different measurments.
#
# When the grouped quota allocation is calculated the full allocaiton utilisation and rates need calculating.

# %% [markdown]
# **UK data aggregation**

# %%
uk_agg_origin = uk3.groupby(["quota_origin","quota_unit_final"], as_index = False).agg({"quota_volume":"sum", 
                                                                                        "remaining_balance":"sum",
                                                                                       "quota_number":"count"})
uk_agg_origin["source"] = "UK" 

# calculate quota allocation usage and utilisation rate
uk_agg_origin["usage"] = uk_agg_origin["quota_volume"] - uk_agg_origin["remaining_balance"]
uk_agg_origin["fill_rate"] = uk_agg_origin["usage"] / uk_agg_origin["quota_volume"]

# remove remaining balance as not needed for outputs

uk_agg_origin = uk_agg_origin.drop("remaining_balance",1)

# relocate columns (one option)
#col = uk_agg_origin[["usage","fill_rate"]]
#uk_agg_origin.drop(labels=[['usage',"fill_rate"]], axis=1, inplace = True)
#uk_agg_origin.insert(3,"usage",col)

# small df so can more easily name column order:

uk_agg_origin = uk_agg_origin[["quota_origin","quota_unit_final","quota_volume","usage","fill_rate","quota_number","source"]]

uk_agg_origin
# Out:
#    quota_origin   quota_unit_final    quota_volume           usage  fill_rate  \
# 0       Albania          Kilograms    384000.00000         0.00000    0.00000
# 1       Albania             Litres    163400.00000         0.00000    0.00000
# 2        Canada          Kilograms 149769000.00000   5861431.21000    0.03914
# 3        Canada    Number of items   3152000.00000     55707.00000    0.01767
# 4        Canada  Square metre (m2)  13222000.00000         0.00000    0.00000
# ..          ...                ...             ...             ...        ...
# 61      Tunisia          Kilograms   9615400.00000     45300.00000    0.00471
# 62      Tunisia             Litres    639700.00000         0.00000    0.00000
# 63       Turkey          Kilograms 446451000.00000 280871448.63300    0.62912
# 64      Ukraine          Kilograms 417412000.00000  65218829.00000    0.15625
# 65      Vietnam          Kilograms  43724000.00000  13171219.00000    0.30124
#
#     quota_number source
# 0              7     UK
# 1              3     UK
# 2             44     UK
# 3             20     UK
# 4              8     UK
# ..           ...    ...
# 61            11     UK
# 62             2     UK
# 63            64     UK
# 64            46     UK
# 65            16     UK
#
# [66 rows x 7 columns]

# %%
uk_agg_grouping = uk3.groupby(["grouping","quota_unit_final"], as_index = False).agg({"quota_volume":"sum", 
                                                                                      "remaining_balance":"sum",
                                                                                     "quota_number":"count"})
uk_agg_grouping["source"] = "UK" 

# calculate quota allocation usage and utilisation rate
uk_agg_grouping["usage"] = uk_agg_grouping["quota_volume"] - uk_agg_grouping["remaining_balance"]
uk_agg_grouping["fill_rate"] = uk_agg_grouping["usage"] / uk_agg_grouping["quota_volume"]

# remove remaining balance as not needed for outputs

uk_agg_grouping = uk_agg_grouping.drop("remaining_balance",1)

# small df so can more easily name column order:

uk_agg_grouping = uk_agg_grouping[["grouping","quota_unit_final","quota_volume","usage","fill_rate","quota_number","source"]]

uk_agg_grouping.head()
# Out:
#            grouping           quota_unit_final    quota_volume         usage  \
# 0           Albania                  Kilograms    384000.00000       0.00000
# 1           Albania                     Litres    163400.00000       0.00000
# 2  Andean countries                  Kilograms 101918000.00000 2602643.31200
# 3  Andean countries  Litre pure (100%) alcohol     45100.00000       0.00000
# 4  Andean countries                     Litres      1700.00000       0.00000
#
#    fill_rate  quota_number source
# 0    0.00000             7     UK
# 1    0.00000             3     UK
# 2    0.02554           112     UK
# 3    0.00000             2     UK
# 4    0.00000             1     UK

# %%
uk_agg_region = uk3.groupby(["region","quota_unit_final"], as_index = False).agg({"quota_volume":"sum", 
                                                                                  "remaining_balance":"sum",
                                                                                 "quota_number":"count"})
uk_agg_region["source"] = "UK" 

uk_agg_region["usage"] = uk_agg_region["quota_volume"] - uk_agg_region["remaining_balance"]
uk_agg_region["fill_rate"] = uk_agg_region["usage"] / uk_agg_region["quota_volume"]

# remove remaining balance as not needed for outputs

uk_agg_region = uk_agg_region.drop("remaining_balance",1)

# small df so can more easily name column order:

uk_agg_region = uk_agg_region[["region","quota_unit_final","quota_volume","usage","fill_rate","quota_number","source"]]

uk_agg_region
# Out:
#                         region           quota_unit_final    quota_volume  \
# 0                       Africa                  Kilograms 314629400.00000
# 1                       Africa                     Litres  72122600.00000
# 2                 Asia Pacific                  Kilograms 237435000.00000
# 3                 Asia Pacific          Square metre (m2)   1068320.00000
# 4               Eastern Europe                  Kilograms 904875906.00000
# 5               Eastern Europe                     Litres   8085726.30000
# 6                 The Americas                  Kilograms 538510273.00000
# 7                 The Americas  Litre pure (100%) alcohol    196400.00000
# 8                 The Americas                     Litres      1700.00000
# 9                 The Americas            Number of items  23468686.00000
# 10                The Americas            Number of pairs   2043000.00000
# 11                The Americas          Square metre (m2)  13222000.00000
# 12  Wider Europe & Middle East                  Kilograms 157551652.00000
# 13  Wider Europe & Middle East                     Litres    124600.00000
# 14  Wider Europe & Middle East            Number of items     17942.00000
#
#              usage  fill_rate  quota_number source
# 0  185740879.04000    0.59035            60     UK
# 1   62438545.17600    0.86573             4     UK
# 2  110682361.00000    0.46616            46     UK
# 3          0.00000    0.00000             1     UK
# 4  346090277.63300    0.38247           138     UK
# 5     234283.80000    0.02897            11     UK
# 6   71164672.66500    0.13215           237     UK
# 7     136676.00000    0.69591             4     UK
# 8          0.00000    0.00000             1     UK
# 9      55707.00000    0.00237           139     UK
# 10         0.00000    0.00000             4     UK
# 11         0.00000    0.00000             8     UK
# 12  21094225.21200    0.13389           153     UK
# 13    121600.00000    0.97592             2     UK
# 14         0.00000    0.00000             2     UK

# %%
print(uk_agg_origin.shape,uk_agg_grouping.shape,uk_agg_region.shape)
# Out:
# (66, 7) (46, 7) (15, 7)

# %% [markdown]
# **EU data aggregation**

# %%
eu_agg_origin = eu.groupby(["origin","quota_unit_final"], as_index = False).agg({"volume":"sum", 
                                                                                  "eu_usage":"sum",
                                                                                  "quota_number":"count"})
eu_agg_origin["source"] = "EU" 

# rename origin and usage to combine with UK data:

eu_agg_origin.rename(columns = {'origin':'quota_origin', 'eu_usage':'usage', "volume":"quota_volume"}, inplace = True)

# calculate utilisaiton (fill rate)

eu_agg_origin["fill_rate"] = eu_agg_origin["usage"] / eu_agg_origin["quota_volume"]

col = eu_agg_origin["fill_rate"]
eu_agg_origin.drop(labels=["fill_rate"], axis=1, inplace = True)
eu_agg_origin.insert(4,"fill_rate",col)

eu_agg_origin
# Out:
#    quota_origin   quota_unit_final     quota_volume            usage  \
# 0       Albania          Kilograms    2810000.00000    1673986.00000
# 1       Albania             Litres     700000.00000       4038.00000
# 2        Canada          Kilograms  370141000.00000    7833365.20700
# 3        Canada    Number of items    3203875.50000     199500.40000
# 4        Canada  Square metre (m2)   16191000.00000      10274.63900
# ..          ...                ...              ...              ...
# 57      Tunisia          Kilograms  126299000.00000   68455753.00000
# 58      Tunisia             Litres   23520000.00000      15818.00000
# 59       Turkey          Kilograms 4045301876.00400 1799497888.22100
# 60      Ukraine          Kilograms 6716435736.75000 3154710277.55700
# 61      Vietnam          Kilograms  130914973.00000   39727582.00000
#
#     fill_rate  quota_number source
# 0     0.59572             7     EU
# 1     0.00577             2     EU
# 2     0.02116            41     EU
# 3     0.06227            20     EU
# 4     0.00063             9     EU
# ..        ...           ...    ...
# 57    0.54201            11     EU
# 58    0.00067             2     EU
# 59    0.44484            68     EU
# 60    0.46970            77     EU
# 61    0.30346            17     EU
#
# [62 rows x 7 columns]

# %%
eu_agg_origin = eu.groupby(["origin","quota_unit_final"], as_index = False).agg({"volume":"sum", 
                                                                                  "eu_usage":"sum",
                                                                                  "quota_number":"count"})
eu_agg_origin["source"] = "EU" 

# rename origin and usage to combine with UK data:

eu_agg_origin.rename(columns = {'origin':'quota_origin', 'eu_usage':'usage', "volume":"quota_volume"}, inplace = True)

# calculate utilisaiton (fill rate)

eu_agg_origin["fill_rate"] = eu_agg_origin["usage"] / eu_agg_origin["quota_volume"]

col = eu_agg_origin["fill_rate"]
eu_agg_origin.drop(labels=["fill_rate"], axis=1, inplace = True)
eu_agg_origin.insert(4,"fill_rate",col)

eu_agg_origin
# Out:
#    quota_origin   quota_unit_final     quota_volume            usage  \
# 0       Albania          Kilograms    2810000.00000    1673986.00000
# 1       Albania             Litres     700000.00000       4038.00000
# 2        Canada          Kilograms  370141000.00000    7833365.20700
# 3        Canada    Number of items    3203875.50000     199500.40000
# 4        Canada  Square metre (m2)   16191000.00000      10274.63900
# ..          ...                ...              ...              ...
# 57      Tunisia          Kilograms  126299000.00000   68455753.00000
# 58      Tunisia             Litres   23520000.00000      15818.00000
# 59       Turkey          Kilograms 4045301876.00400 1799497888.22100
# 60      Ukraine          Kilograms 6716435736.75000 3154710277.55700
# 61      Vietnam          Kilograms  130914973.00000   39727582.00000
#
#     fill_rate  quota_number source
# 0     0.59572             7     EU
# 1     0.00577             2     EU
# 2     0.02116            41     EU
# 3     0.06227            20     EU
# 4     0.00063             9     EU
# ..        ...           ...    ...
# 57    0.54201            11     EU
# 58    0.00067             2     EU
# 59    0.44484            68     EU
# 60    0.46970            77     EU
# 61    0.30346            17     EU
#
# [62 rows x 7 columns]

# %%
eu_agg_grouping = eu.groupby(["grouping","quota_unit_final"], as_index = False).agg({"volume":"sum", 
                                                                                  "eu_usage":"sum",
                                                                                  "quota_number":"count"})
eu_agg_grouping["source"] = "EU" 

# rename origin and usage to combine with UK data:

eu_agg_grouping.rename(columns = {'eu_usage':'usage', "volume":"quota_volume"}, inplace = True)

# calculate utilisaiton (fill rate)

eu_agg_grouping["fill_rate"] = eu_agg_grouping["usage"] / eu_agg_grouping["quota_volume"]

col = eu_agg_grouping["fill_rate"]
eu_agg_grouping.drop(labels=["fill_rate"], axis=1, inplace = True)
eu_agg_grouping.insert(4,"fill_rate",col)

eu_agg_grouping.head()
# Out:
#            grouping           quota_unit_final    quota_volume          usage  \
# 0           Albania                  Kilograms   2810000.00000  1673986.00000
# 1           Albania                     Litres    700000.00000     4038.00000
# 2  Andean countries                  Kilograms 707581000.00000 84464432.67000
# 3  Andean countries  Litre pure (100%) alcohol    390000.00000        0.00000
# 4  Andean countries                     Litres     28000.00000        0.00000
#
#    fill_rate  quota_number source
# 0    0.59572             7     EU
# 1    0.00577             2     EU
# 2    0.11937            77     EU
# 3    0.00000             2     EU
# 4    0.00000             1     EU

# %%
eu_agg_region = eu.groupby(["region","quota_unit_final"], as_index = False).agg({"volume":"sum", 
                                                                                  "eu_usage":"sum",
                                                                                  "quota_number":"count"})
eu_agg_region["source"] = "EU" 

# rename origin and usage to combine with UK data:

eu_agg_region.rename(columns = {'eu_usage':'usage', "volume":"quota_volume"}, inplace = True)

# calculate utilisaiton (fill rate)

eu_agg_region["fill_rate"] = eu_agg_region["usage"] / eu_agg_region["quota_volume"]

col = eu_agg_region["fill_rate"]
eu_agg_region.drop(labels=["fill_rate"], axis=1, inplace = True)
eu_agg_region.insert(4,"fill_rate",col)

eu_agg_region.head()
# Out:
#            region   quota_unit_final      quota_volume            usage  \
# 0          Africa          Kilograms  1250952313.00000  701944589.51200
# 1          Africa             Litres   137756000.00000   96679497.62500
# 2    Asia Pacific          Kilograms  4049103800.09500 1283041327.80100
# 3    Asia Pacific  Square metre (m2)    17805290.00000    5876166.19700
# 4  Eastern Europe          Kilograms 12285437042.75400 5599447746.73800
#
#    fill_rate  quota_number source
# 0    0.56113            58     EU
# 1    0.70182             4     EU
# 2    0.31687            83     EU
# 3    0.33002             1     EU
# 4    0.45578           190     EU

# %% [markdown]
# **combine aggregated data outputs:**

# %%
trq_agg_origin = pd.concat([uk_agg_origin,eu_agg_origin])
print(trq_agg_origin.shape)

# re-order:
trq_agg_origin = trq_agg_origin.sort_values(by=['quota_origin',"quota_unit_final","source"], ascending=True)
trq_agg_origin.head()
# Out:
# (128, 7)
#   quota_origin quota_unit_final    quota_volume         usage  fill_rate  \
# 0      Albania        Kilograms   2810000.00000 1673986.00000    0.59572
# 0      Albania        Kilograms    384000.00000       0.00000    0.00000
# 1      Albania           Litres    700000.00000    4038.00000    0.00577
# 1      Albania           Litres    163400.00000       0.00000    0.00000
# 2       Canada        Kilograms 370141000.00000 7833365.20700    0.02116
#
#    quota_number source
# 0             7     EU
# 0             7     UK
# 1             2     EU
# 1             3     UK
# 2            41     EU

# %%
trq_agg_grouping = pd.concat([uk_agg_grouping,eu_agg_grouping])
print(trq_agg_grouping.shape)

# re-order:
trq_agg_grouping = trq_agg_grouping.sort_values(by=['grouping',"quota_unit_final","source"], ascending=True)
trq_agg_grouping
# Out:
# (91, 7)
#             grouping quota_unit_final     quota_volume            usage  \
# 0            Albania        Kilograms    2810000.00000    1673986.00000
# 0            Albania        Kilograms     384000.00000          0.00000
# 1            Albania           Litres     700000.00000       4038.00000
# 1            Albania           Litres     163400.00000          0.00000
# 2   Andean countries        Kilograms  707581000.00000   84464432.67000
# ..               ...              ...              ...              ...
# 43            Turkey        Kilograms  446451000.00000  280871448.63300
# 43           Ukraine        Kilograms 6716435736.75000 3154710277.55700
# 44           Ukraine        Kilograms  417412000.00000   65218829.00000
# 44           Vietnam        Kilograms  130914973.00000   39727582.00000
# 45           Vietnam        Kilograms   43724000.00000   13171219.00000
#
#     fill_rate  quota_number source
# 0     0.59572             7     EU
# 0     0.00000             7     UK
# 1     0.00577             2     EU
# 1     0.00000             3     UK
# 2     0.11937            77     EU
# ..        ...           ...    ...
# 43    0.62912            64     UK
# 43    0.46970            77     EU
# 44    0.15625            46     UK
# 44    0.30346            17     EU
# 45    0.30124            16     UK
#
# [91 rows x 7 columns]

# %%
trq_agg_region = pd.concat([uk_agg_region,eu_agg_region])
print(trq_agg_region.shape)

# re-order:
trq_agg_region = trq_agg_region.sort_values(by=['region',"quota_unit_final","source"], ascending=True)
trq_agg_region
# Out:
# (30, 7)
#                         region           quota_unit_final      quota_volume  \
# 0                       Africa                  Kilograms  1250952313.00000
# 0                       Africa                  Kilograms   314629400.00000
# 1                       Africa                     Litres   137756000.00000
# 1                       Africa                     Litres    72122600.00000
# 2                 Asia Pacific                  Kilograms  4049103800.09500
# 2                 Asia Pacific                  Kilograms   237435000.00000
# 3                 Asia Pacific          Square metre (m2)    17805290.00000
# 3                 Asia Pacific          Square metre (m2)     1068320.00000
# 4               Eastern Europe                  Kilograms 12285437042.75400
# 4               Eastern Europe                  Kilograms   904875906.00000
# 5               Eastern Europe                     Litres    60430000.00000
# 5               Eastern Europe                     Litres     8085726.30000
# 6                 The Americas                  Kilograms  1763726000.00000
# 6                 The Americas                  Kilograms   538510273.00000
# 7                 The Americas  Litre pure (100%) alcohol     1435000.00000
# 7                 The Americas  Litre pure (100%) alcohol      196400.00000
# 8                 The Americas                     Litres       28000.00000
# 8                 The Americas                     Litres        1700.00000
# 9                 The Americas            Number of items   104926375.50000
# 9                 The Americas            Number of items    23468686.00000
# 10                The Americas            Number of pairs    15362500.00000
# 10                The Americas            Number of pairs     2043000.00000
# 11                The Americas          Square metre (m2)    16191000.00000
# 11                The Americas          Square metre (m2)    13222000.00000
# 12  Wider Europe & Middle East                  Kilograms  2830630662.27500
# 12  Wider Europe & Middle East                  Kilograms   157551652.00000
# 13  Wider Europe & Middle East                     Litres    41484200.00000
# 13  Wider Europe & Middle East                     Litres      124600.00000
# 14  Wider Europe & Middle East            Number of items      129920.00000
# 14  Wider Europe & Middle East            Number of items       17942.00000
#
#               usage  fill_rate  quota_number source
# 0   701944589.51200    0.56113            58     EU
# 0   185740879.04000    0.59035            60     UK
# 1    96679497.62500    0.70182             4     EU
# 1    62438545.17600    0.86573             4     UK
# 2  1283041327.80100    0.31687            83     EU
# 2   110682361.00000    0.46616            46     UK
# 3     5876166.19700    0.33002             1     EU
# 3           0.00000    0.00000             1     UK
# 4  5599447746.73800    0.45578           190     EU
# 4   346090277.63300    0.38247           138     UK
# 5    46257038.47000    0.76546             9     EU
# 5      234283.80000    0.02897            11     UK
# 6   328407405.06800    0.18620           169     EU
# 6    71164672.66500    0.13215           237     UK
# 7     1045000.00000    0.72822             4     EU
# 7      136676.00000    0.69591             4     UK
# 8           0.00000    0.00000             1     EU
# 8           0.00000    0.00000             1     UK
# 9      203121.40000    0.00194            75     EU
# 9       55707.00000    0.00237           139     UK
# 10          0.00000    0.00000             6     EU
# 10          0.00000    0.00000             4     UK
# 11      10274.63900    0.00063             9     EU
# 11          0.00000    0.00000             8     UK
# 12  577313617.82200    0.20395           203     EU
# 12   21094225.21200    0.13389           153     UK
# 13   11210720.69300    0.27024             4     EU
# 13     121600.00000    0.97592             2     UK
# 14          0.00000    0.00000             1     EU
# 14          0.00000    0.00000             2     UK

# %% [markdown]
# ### 2b. UK quota aggregations using function:

# %% [markdown]
# There is duplication of code when writing out the groupby aggregation each time. This can be made more efficient with the use of creating a single function.

# %%
def uk_aggFunc(data, group_type,sector_group = None):
    if(sector_group == None):
        cols = [group_type,"quota_unit_final"]
        final_cols = [group_type,"quota_unit_final","quota_volume","usage","fill_rate","quota_number","source"]
    else:
        cols = [group_type,sector_group,"quota_unit_final"]
        final_cols = [group_type,sector_group,"quota_unit_final","quota_volume","usage","fill_rate","quota_number","source"]
        

    df_agg = data.groupby(cols, as_index = False).agg({"quota_volume":"sum", "remaining_balance":"sum","quota_number":"count"})
    df_agg["source"] = "UK" 
    df_agg["usage"] = df_agg["quota_volume"] - df_agg["remaining_balance"]
    df_agg["fill_rate"] = df_agg["usage"] / df_agg["quota_volume"]
    df_agg = df_agg[final_cols]
    return(df_agg)

# %%
df_region = uk_aggFunc(uk3,"region")
df_grouping = uk_aggFunc(uk3,"grouping")
df_origin = uk_aggFunc(uk3,"quota_origin")

print(df_region.shape,df_grouping.shape,df_origin.shape)
# Out:
# (15, 7) (46, 7) (66, 7)

# %% [markdown]
# Writing and using a functon to remove repetitive use of similar code is preferable.

# %% [markdown]
# ### 3. Compare outputs:

# %% [markdown]
# Compare R generated TRQ grouping outputs to python as a quality assurance check:

# %%
trq_agg_region2 = pd.read_excel('../rsp_uk_trq_qa/outputs/trq_data_output11.xlsx',"region_level")
trq_agg_grouping2 = pd.read_excel('../rsp_uk_trq_qa/outputs/trq_data_output11.xlsx',"grouping_level")
trq_agg_origin2 = pd.read_excel('../rsp_uk_trq_qa/outputs/trq_data_output11.xlsx',"country_level")
print(trq_agg_origin2.shape,trq_agg_grouping2.shape,trq_agg_region2.shape)
# Out:
# (127, 10) (90, 9) (30, 7)

# %%
# compare df shapes:
print(trq_agg_origin.shape,trq_agg_grouping.shape,trq_agg_region.shape)
# Out:
# (128, 7) (91, 7) (30, 7)

# %%
# match dfs together. Need joinId first:

trq_agg_region["joinID"] = trq_agg_region["region"]+trq_agg_region["quota_unit_final"]+trq_agg_region["source"]
trq_agg_region2["joinID"] = trq_agg_region2["region"]+trq_agg_region2["quota_unit_final"]+trq_agg_region2["source"]

# join:
trq_agg_region_qa = pd.merge(trq_agg_region,trq_agg_region2[["total_quota_volume",
                                                            "total_quota_usage",
                                                            "total_allocation_fill_rate",
                                                           "joinID"]],on = "joinID", how = "left")
trq_agg_region_qa.shape
# Out:
# (30, 11)

# %%
# compare values:

trq_agg_region_qa["volume_check"] = trq_agg_region_qa["quota_volume"]-trq_agg_region_qa["total_quota_volume"]
trq_agg_region_qa["usage_check"] = trq_agg_region_qa["usage"]-trq_agg_region_qa["total_quota_usage"]
trq_agg_region_qa["fill_rate_check"] = trq_agg_region_qa["fill_rate"]-trq_agg_region_qa["total_allocation_fill_rate"]

trq_agg_region_qa
# Out:
#                         region           quota_unit_final      quota_volume  \
# 0                       Africa                  Kilograms  1250952313.00000
# 1                       Africa                  Kilograms   314629400.00000
# 2                       Africa                     Litres   137756000.00000
# 3                       Africa                     Litres    72122600.00000
# 4                 Asia Pacific                  Kilograms  4049103800.09500
# 5                 Asia Pacific                  Kilograms   237435000.00000
# 6                 Asia Pacific          Square metre (m2)    17805290.00000
# 7                 Asia Pacific          Square metre (m2)     1068320.00000
# 8               Eastern Europe                  Kilograms 12285437042.75400
# 9               Eastern Europe                  Kilograms   904875906.00000
# 10              Eastern Europe                     Litres    60430000.00000
# 11              Eastern Europe                     Litres     8085726.30000
# 12                The Americas                  Kilograms  1763726000.00000
# 13                The Americas                  Kilograms   538510273.00000
# 14                The Americas  Litre pure (100%) alcohol     1435000.00000
# 15                The Americas  Litre pure (100%) alcohol      196400.00000
# 16                The Americas                     Litres       28000.00000
# 17                The Americas                     Litres        1700.00000
# 18                The Americas            Number of items   104926375.50000
# 19                The Americas            Number of items    23468686.00000
# 20                The Americas            Number of pairs    15362500.00000
# 21                The Americas            Number of pairs     2043000.00000
# 22                The Americas          Square metre (m2)    16191000.00000
# 23                The Americas          Square metre (m2)    13222000.00000
# 24  Wider Europe & Middle East                  Kilograms  2830630662.27500
# 25  Wider Europe & Middle East                  Kilograms   157551652.00000
# 26  Wider Europe & Middle East                     Litres    41484200.00000
# 27  Wider Europe & Middle East                     Litres      124600.00000
# 28  Wider Europe & Middle East            Number of items      129920.00000
# 29  Wider Europe & Middle East            Number of items       17942.00000
#
#               usage  fill_rate  quota_number source  \
# 0   701944589.51200    0.56113            58     EU
# 1   185740879.04000    0.59035            60     UK
# 2    96679497.62500    0.70182             4     EU
# 3    62438545.17600    0.86573             4     UK
# 4  1283041327.80100    0.31687            83     EU
# 5   110682361.00000    0.46616            46     UK
# 6     5876166.19700    0.33002             1     EU
# 7           0.00000    0.00000             1     UK
# 8  5599447746.73800    0.45578           190     EU
# 9   346090277.63300    0.38247           138     UK
# 10   46257038.47000    0.76546             9     EU
# 11     234283.80000    0.02897            11     UK
# 12  328407405.06800    0.18620           169     EU
# 13   71164672.66500    0.13215           237     UK
# 14    1045000.00000    0.72822             4     EU
# 15     136676.00000    0.69591             4     UK
# 16          0.00000    0.00000             1     EU
# 17          0.00000    0.00000             1     UK
# 18     203121.40000    0.00194            75     EU
# 19      55707.00000    0.00237           139     UK
# 20          0.00000    0.00000             6     EU
# 21          0.00000    0.00000             4     UK
# 22      10274.63900    0.00063             9     EU
# 23          0.00000    0.00000             8     UK
# 24  577313617.82200    0.20395           203     EU
# 25   21094225.21200    0.13389           153     UK
# 26   11210720.69300    0.27024             4     EU
# 27     121600.00000    0.97592             2     UK
# 28          0.00000    0.00000             1     EU
# 29          0.00000    0.00000             2     UK
#
#                                          joinID  total_quota_volume  \
# 0                             AfricaKilogramsEU    1250952313.00000
# 1                             AfricaKilogramsUK     314629400.00000
# 2                                AfricaLitresEU     137756000.00000
# 3                                AfricaLitresUK      72122600.00000
# 4                       Asia PacificKilogramsEU    4049103800.09500
# 5                       Asia PacificKilogramsUK     221394000.00000
# 6               Asia PacificSquare metre (m2)EU      17805290.00000
# 7               Asia PacificSquare metre (m2)UK       1068320.00000
# 8                     Eastern EuropeKilogramsEU   12285437042.75400
# 9                     Eastern EuropeKilogramsUK     759913906.00000
# 10                       Eastern EuropeLitresEU      60430000.00000
# 11                       Eastern EuropeLitresUK       7518256.75263
# 12                      The AmericasKilogramsEU    1763726000.00000
# 13                      The AmericasKilogramsUK     538510273.00000
# 14      The AmericasLitre pure (100%) alcoholEU       1435000.00000
# 15      The AmericasLitre pure (100%) alcoholUK        196400.00000
# 16                         The AmericasLitresEU         28000.00000
# 17                         The AmericasLitresUK          1700.00000
# 18                The AmericasNumber of itemsEU     104926375.50000
# 19                The AmericasNumber of itemsUK      23468686.00000
# 20                The AmericasNumber of pairsEU      15362500.00000
# 21                The AmericasNumber of pairsUK       2043000.00000
# 22              The AmericasSquare metre (m2)EU      16191000.00000
# 23              The AmericasSquare metre (m2)UK      13222000.00000
# 24        Wider Europe & Middle EastKilogramsEU    2830630662.27500
# 25        Wider Europe & Middle EastKilogramsUK     139569652.00000
# 26           Wider Europe & Middle EastLitresEU      41484200.00000
# 27           Wider Europe & Middle EastLitresUK        124600.00000
# 28  Wider Europe & Middle EastNumber of itemsEU        129920.00000
# 29  Wider Europe & Middle EastNumber of itemsUK         17942.00000
#
#     total_quota_usage  total_allocation_fill_rate    volume_check  \
# 0     701944589.51200                     0.56113         0.00000
# 1     186775277.74000                     0.59364         0.00000
# 2      96679497.62500                     0.70182         0.00000
# 3      62438545.17600                     0.86573         0.00000
# 4    1283041327.80100                     0.31687         0.00000
# 5     110682361.00000                     0.49993  16041000.00000
# 6       5876166.19700                     0.33002         0.00000
# 7             0.00000                     0.00000         0.00000
# 8    5599447746.73800                     0.45578         0.00000
# 9     314154947.63300                     0.41341 144962000.00000
# 10     46257038.47000                     0.76546         0.00000
# 11       234283.50003                     0.03116    567469.54737
# 12    328407405.06800                     0.18620         0.00000
# 13     71209672.66500                     0.13223         0.00000
# 14      1045000.00000                     0.72822         0.00000
# 15       136676.00000                     0.69591         0.00000
# 16            0.00000                     0.00000         0.00000
# 17            0.00000                     0.00000         0.00000
# 18       203121.40000                     0.00194         0.00000
# 19        55707.00000                     0.00237         0.00000
# 20            0.00000                     0.00000         0.00000
# 21            0.00000                     0.00000         0.00000
# 22        10274.63900                     0.00063         0.00000
# 23            0.00000                     0.00000         0.00000
# 24    577313617.82200                     0.20395        -0.00000
# 25     21089725.21200                     0.15111  17982000.00000
# 26     11210720.69300                     0.27024         0.00000
# 27       121600.00000                     0.97592         0.00000
# 28            0.00000                     0.00000         0.00000
# 29            0.00000                     0.00000         0.00000
#
#       usage_check  fill_rate_check
# 0         0.00000          0.00000
# 1  -1034398.70000         -0.00329
# 2         0.00000         -0.00000
# 3         0.00000          0.00000
# 4         0.00000         -0.00000
# 5         0.00000         -0.03378
# 6         0.00000         -0.00000
# 7         0.00000          0.00000
# 8         0.00000          0.00000
# 9  31935330.00000         -0.03094
# 10        0.00000         -0.00000
# 11        0.29997         -0.00219
# 12        0.00000          0.00000
# 13   -45000.00000         -0.00008
# 14        0.00000          0.00000
# 15        0.00000          0.00000
# 16        0.00000          0.00000
# 17        0.00000          0.00000
# 18        0.00000         -0.00000
# 19        0.00000         -0.00000
# 20        0.00000          0.00000
# 21        0.00000          0.00000
# 22        0.00000         -0.00000
# 23        0.00000          0.00000
# 24        0.00000          0.00000
# 25     4500.00000         -0.01722
# 26        0.00000         -0.00000
# 27        0.00000          0.00000
# 28        0.00000          0.00000
# 29        0.00000          0.00000

# %%
trq_agg_region_qa.dtypes
# Out:
# region                         object
# quota_unit_final               object
# quota_volume                  float64
# usage                         float64
# fill_rate                     float64
# quota_number                    int64
# source                         object
# joinID                         object
# total_quota_volume            float64
# total_quota_usage             float64
# total_allocation_fill_rate    float64
# volume_check                  float64
# usage_check                   float64
# fill_rate_check               float64
# dtype: object

# %%
# country groupings QA:

trq_agg_grouping["joinID"] = trq_agg_grouping["grouping"]+trq_agg_grouping["quota_unit_final"]+trq_agg_grouping["source"]
trq_agg_grouping2["joinID"] = trq_agg_grouping2["grouping"]+trq_agg_grouping2["quota_unit_final"]+trq_agg_grouping2["source"]

# join:
trq_agg_grouping_qa = pd.merge(trq_agg_grouping,trq_agg_grouping2[["total_quota_volume",
                                                            "total_quota_usage",
                                                            "total_allocation_fill_rate",
                                                           "joinID"]],on = "joinID", how = "left")
trq_agg_grouping_qa.shape
# Out:
# (91, 11)

# %%
# compare values:

trq_agg_grouping_qa["volume_check"] = trq_agg_grouping_qa["quota_volume"]-trq_agg_grouping_qa["total_quota_volume"]
trq_agg_grouping_qa["usage_check"] = trq_agg_grouping_qa["usage"]-trq_agg_grouping_qa["total_quota_usage"]
trq_agg_grouping_qa["fill_rate_check"] = trq_agg_grouping_qa["fill_rate"]-trq_agg_grouping_qa["total_allocation_fill_rate"]

trq_agg_grouping_qa.tail(50)
# Out:
#            grouping   quota_unit_final     quota_volume            usage  \
# 41           Israel             Litres     121600.00000     121600.00000
# 42           Israel    Number of items     129920.00000          0.00000
# 43           Israel    Number of items      17695.00000          0.00000
# 44            Japan          Kilograms   79779789.93000   16879143.64100
# 45            Japan          Kilograms    2958000.00000          0.00000
# 46           Jordan          Kilograms   24000000.00000       7568.00000
# 47           Jordan          Kilograms    2180000.00000       6534.00000
# 48           Kosovo          Kilograms      35000.00000          0.00000
# 49           Kosovo          Kilograms      70000.00000          0.00000
# 50           Kosovo             Litres    5000000.00000    3398564.50000
# 51           Kosovo             Litres     749100.00000          0.00000
# 52          Lebanon          Kilograms  214500000.00000     662097.50000
# 53          Lebanon          Kilograms   31016000.00000     118156.95100
# 54           Mexico          Kilograms  370910000.00000   37871626.14100
# 55           Mexico          Kilograms  193965274.00000    5219659.40000
# 56          Moldova          Kilograms  486186847.00000  157064088.96000
# 57          Moldova          Kilograms   10789000.00000          0.00000
# 58          Morocco          Kilograms  560158399.00000  396049789.23000
# 59          Morocco          Kilograms  137583000.00000  100372342.84000
# 60  North Macedonia          Kilograms  252309541.00000   71083442.00000
# 61  North Macedonia          Kilograms    3893000.00000          0.00000
# 62  North Macedonia             Litres   48000000.00000   42197701.22000
# 63  North Macedonia             Litres    6605700.00000     234283.50000
# 64           Serbia          Kilograms  782138042.00000  415418064.00000
# 65           Serbia          Kilograms   25846906.00000          0.00000
# 66           Serbia             Litres    6730000.00000     656734.75000
# 67           Serbia             Litres     567526.30000          0.30000
# 68        Singapore          Kilograms    1250000.00000          0.00000
# 69        Singapore          Kilograms     350000.00000          0.00000
# 70    South Africa           Kilograms  297779500.00000  189836708.45000
# 71    South Africa           Kilograms  118793000.00000   73539850.80000
# 72    South Africa              Litres  114236000.00000   96663679.62500
# 73    South Africa              Litres   71482900.00000   62438545.17600
# 74      South Korea          Kilograms 3837159037.16500 1226434602.16000
# 75      South Korea          Kilograms  190403000.00000   97511142.00000
# 76      South Korea  Square metre (m2)   17805290.00000    5876166.19700
# 77      South Korea  Square metre (m2)    1068320.00000          0.00000
# 78      Switzerland          Kilograms 1545399530.27500  270943709.44000
# 79      Switzerland          Kilograms    2838270.00000          0.00000
# 80      Switzerland    Number of items        247.00000          0.00000
# 81          Tunisia          Kilograms  126299000.00000   68455753.00000
# 82          Tunisia          Kilograms    9615400.00000      45300.00000
# 83          Tunisia             Litres   23520000.00000      15818.00000
# 84          Tunisia             Litres     639700.00000          0.00000
# 85           Turkey          Kilograms 4045301876.00400 1799497888.22100
# 86           Turkey          Kilograms  446451000.00000  280871448.63300
# 87          Ukraine          Kilograms 6716435736.75000 3154710277.55700
# 88          Ukraine          Kilograms  417412000.00000   65218829.00000
# 89          Vietnam          Kilograms  130914973.00000   39727582.00000
# 90          Vietnam          Kilograms   43724000.00000   13171219.00000
#
#     fill_rate  quota_number source                          joinID  \
# 41    1.00000             1     UK                  IsraelLitresUK
# 42    0.00000             1     EU         IsraelNumber of itemsEU
# 43    0.00000             1     UK         IsraelNumber of itemsUK
# 44    0.21157            11     EU                JapanKilogramsEU
# 45    0.00000             2     UK                JapanKilogramsUK
# 46    0.00032             2     EU               JordanKilogramsEU
# 47    0.00300             2     UK               JordanKilogramsUK
# 48    0.00000             2     EU               KosovoKilogramsEU
# 49    0.00000             3     UK               KosovoKilogramsUK
# 50    0.67971             3     EU                  KosovoLitresEU
# 51    0.00000             3     UK                  KosovoLitresUK
# 52    0.00309            17     EU              LebanonKilogramsEU
# 53    0.00381            19     UK              LebanonKilogramsUK
# 54    0.10210            23     EU               MexicoKilogramsEU
# 55    0.02691            49     UK               MexicoKilogramsUK
# 56    0.32305            13     EU              MoldovaKilogramsEU
# 57    0.00000             7     UK              MoldovaKilogramsUK
# 58    0.70703            16     EU              MoroccoKilogramsEU
# 59    0.72954            14     UK              MoroccoKilogramsUK
# 60    0.28173            10     EU      North MacedoniaKilogramsEU
# 61    0.00000             5     UK      North MacedoniaKilogramsUK
# 62    0.87912             2     EU         North MacedoniaLitresEU
# 63    0.03547             3     UK         North MacedoniaLitresUK
# 64    0.53113            12     EU               SerbiaKilogramsEU
# 65    0.00000             5     UK               SerbiaKilogramsUK
# 66    0.09758             2     EU                  SerbiaLitresEU
# 67    0.00000             2     UK                  SerbiaLitresUK
# 68    0.00000             3     EU            SingaporeKilogramsEU
# 69    0.00000             3     UK            SingaporeKilogramsUK
# 70    0.63751            13     EU        South Africa KilogramsEU
# 71    0.61906            14     UK        South Africa KilogramsUK
# 72    0.84618             2     EU           South Africa LitresEU
# 73    0.87348             2     UK           South Africa LitresUK
# 74    0.31962            52     EU          South KoreaKilogramsEU
# 75    0.51213            25     UK          South KoreaKilogramsUK
# 76    0.33002             1     EU  South KoreaSquare metre (m2)EU
# 77    0.00000             1     UK  South KoreaSquare metre (m2)UK
# 78    0.17532            52     EU          SwitzerlandKilogramsEU
# 79    0.00000            31     UK          SwitzerlandKilogramsUK
# 80    0.00000             1     UK    SwitzerlandNumber of itemsUK
# 81    0.54201            11     EU              TunisiaKilogramsEU
# 82    0.00471            11     UK              TunisiaKilogramsUK
# 83    0.00067             2     EU                 TunisiaLitresEU
# 84    0.00000             2     UK                 TunisiaLitresUK
# 85    0.44484            68     EU               TurkeyKilogramsEU
# 86    0.62912            64     UK               TurkeyKilogramsUK
# 87    0.46970            77     EU              UkraineKilogramsEU
# 88    0.15625            46     UK              UkraineKilogramsUK
# 89    0.30346            17     EU              VietnamKilogramsEU
# 90    0.30124            16     UK              VietnamKilogramsUK
#
#     total_quota_volume  total_quota_usage  total_allocation_fill_rate  \
# 41        121600.00000       121600.00000                     1.00000
# 42        129920.00000            0.00000                     0.00000
# 43         17695.00000            0.00000                     0.00000
# 44      79779789.93000     16879143.64100                     0.21157
# 45                 NaN                NaN                         NaN
# 46      24000000.00000         7568.00000                     0.00032
# 47       2180000.00000         6534.00000                     0.00300
# 48         35000.00000            0.00000                     0.00000
# 49         70000.00000            0.00000                     0.00000
# 50       5000000.00000      3398564.50000                     0.67971
# 51        749100.00000            0.00000                     0.00000
# 52     214500000.00000       662097.50000                     0.00309
# 53      31016000.00000       118156.95100                     0.00381
# 54     370910000.00000     37871626.14100                     0.10210
# 55     193965274.00000      5264659.40000                     0.02714
# 56     486186847.00000    157064088.96000                     0.32305
# 57      10789000.00000            0.00000                     0.00000
# 58     560158399.00000    396049789.23000                     0.70703
# 59     137583000.00000    101406741.54000                     0.73706
# 60     252309541.00000     71083442.00000                     0.28173
# 61       3893000.00000            0.00000                     0.00000
# 62      48000000.00000     42197701.22000                     0.87912
# 63       6605700.00000       234283.50000                     0.03547
# 64     782138042.00000    415418064.00000                     0.53113
# 65      25846906.00000            0.00000                     0.00000
# 66       6730000.00000       656734.75000                     0.09758
# 67            56.75263            0.00003                     0.00000
# 68       1250000.00000            0.00000                     0.00000
# 69        350000.00000            0.00000                     0.00000
# 70                 NaN                NaN                         NaN
# 71                 NaN                NaN                         NaN
# 72                 NaN                NaN                         NaN
# 73                 NaN                NaN                         NaN
# 74    3837159037.16500   1226434602.16000                     0.31962
# 75     177320000.00000     97511142.00000                     0.54992
# 76      17805290.00000      5876166.19700                     0.33002
# 77       1068320.00000            0.00000                     0.00000
# 78    1545399530.27500    270943709.44000                     0.17532
# 79       2838270.00000            0.00000                     0.00000
# 80           247.00000            0.00000                     0.00000
# 81     126299000.00000     68455753.00000                     0.54201
# 82       9615400.00000        45300.00000                     0.00471
# 83      23520000.00000        15818.00000                     0.00067
# 84        639700.00000            0.00000                     0.00000
# 85    4045301876.00400   1799497888.22100                     0.44484
# 86     348958000.00000    248991938.63300                     0.71353
# 87    6716435736.75000   3154710277.55700                     0.46970
# 88     369943000.00000     65163009.00000                     0.17614
# 89     130914973.00000     39727582.00000                     0.30346
# 90      43724000.00000     13171219.00000                     0.30124
#
#      volume_check    usage_check  fill_rate_check
# 41        0.00000        0.00000          0.00000
# 42        0.00000        0.00000          0.00000
# 43        0.00000        0.00000          0.00000
# 44       -0.00000        0.00000          0.00000
# 45            NaN            NaN              NaN
# 46        0.00000        0.00000          0.00000
# 47        0.00000        0.00000         -0.00000
# 48        0.00000        0.00000          0.00000
# 49        0.00000        0.00000          0.00000
# 50        0.00000        0.00000          0.00000
# 51        0.00000        0.00000          0.00000
# 52        0.00000        0.00000          0.00000
# 53        0.00000        0.00000         -0.00000
# 54        0.00000        0.00000          0.00000
# 55        0.00000   -45000.00000         -0.00023
# 56        0.00000        0.00000          0.00000
# 57        0.00000        0.00000          0.00000
# 58        0.00000        0.00000         -0.00000
# 59        0.00000 -1034398.70000         -0.00752
# 60        0.00000        0.00000          0.00000
# 61        0.00000        0.00000          0.00000
# 62        0.00000        0.00000         -0.00000
# 63        0.00000        0.00000          0.00000
# 64        0.00000        0.00000         -0.00000
# 65        0.00000        0.00000          0.00000
# 66        0.00000        0.00000          0.00000
# 67   567469.54737        0.29997          0.00000
# 68        0.00000        0.00000          0.00000
# 69        0.00000        0.00000          0.00000
# 70            NaN            NaN              NaN
# 71            NaN            NaN              NaN
# 72            NaN            NaN              NaN
# 73            NaN            NaN              NaN
# 74        0.00000       -0.00000         -0.00000
# 75 13083000.00000        0.00000         -0.03779
# 76        0.00000        0.00000         -0.00000
# 77        0.00000        0.00000          0.00000
# 78       -0.00000        0.00000          0.00000
# 79        0.00000        0.00000          0.00000
# 80        0.00000        0.00000          0.00000
# 81        0.00000        0.00000         -0.00000
# 82        0.00000        0.00000          0.00000
# 83        0.00000        0.00000          0.00000
# 84        0.00000        0.00000          0.00000
# 85       -0.00000        0.00000          0.00000
# 86 97493000.00000 31879510.00000         -0.08441
# 87        0.00000        0.00000          0.00000
# 88 47469000.00000    55820.00000         -0.01990
# 89        0.00000        0.00000          0.00000
# 90        0.00000        0.00000          0.00000

# %%
# country origin QA:


trq_agg_origin["joinID"] = trq_agg_origin["quota_origin"]+trq_agg_origin["quota_unit_final"]+trq_agg_origin["source"]
trq_agg_origin2["joinID"] = trq_agg_origin2["quota_origin"]+trq_agg_origin2["quota_unit_final"]+trq_agg_origin2["source"]

# join:
trq_agg_origin_qa = pd.merge(trq_agg_origin,trq_agg_origin2[["total_quota_volume",
                                                            "total_quota_usage",
                                                            "total_allocation_fill_rate",
                                                           "joinID"]],on = "joinID", how = "left")
trq_agg_origin_qa.shape
# Out:
# (128, 11)

# %%
# compare values:

trq_agg_origin_qa["volume_check"] = trq_agg_origin_qa["quota_volume"]-trq_agg_origin_qa["total_quota_volume"]
trq_agg_origin_qa["usage_check"] = trq_agg_origin_qa["usage"]-trq_agg_origin_qa["total_quota_usage"]
trq_agg_origin_qa["fill_rate_check"] = trq_agg_origin_qa["fill_rate"]-trq_agg_origin_qa["total_allocation_fill_rate"]

trq_agg_origin_qa.head()
# Out:
#   quota_origin quota_unit_final    quota_volume         usage  fill_rate  \
# 0      Albania        Kilograms   2810000.00000 1673986.00000    0.59572
# 1      Albania        Kilograms    384000.00000       0.00000    0.00000
# 2      Albania           Litres    700000.00000    4038.00000    0.00577
# 3      Albania           Litres    163400.00000       0.00000    0.00000
# 4       Canada        Kilograms 370141000.00000 7833365.20700    0.02116
#
#    quota_number source              joinID  total_quota_volume  \
# 0             7     EU  AlbaniaKilogramsEU       2810000.00000
# 1             7     UK  AlbaniaKilogramsUK        384000.00000
# 2             2     EU     AlbaniaLitresEU        700000.00000
# 3             3     UK     AlbaniaLitresUK        163400.00000
# 4            41     EU   CanadaKilogramsEU     370141000.00000
#
#    total_quota_usage  total_allocation_fill_rate  volume_check  usage_check  \
# 0      1673986.00000                     0.59572       0.00000      0.00000
# 1            0.00000                     0.00000       0.00000      0.00000
# 2         4038.00000                     0.00577       0.00000      0.00000
# 3            0.00000                     0.00000       0.00000      0.00000
# 4      7833365.20700                     0.02116       0.00000      0.00000
#
#    fill_rate_check
# 0          0.00000
# 1          0.00000
# 2         -0.00000
# 3          0.00000
# 4         -0.00000

# %% [markdown]
# ### 3b. Create function to upload and QA output files in notebook:

# %%
def uk_trq_data_check(sheetName, group):
    # upload data
    sheet_name = sheetName + "_level"
    file_path = '../rsp_uk_trq_qa/outputs/trq_data_output11.xlsx'
    df = pd.read_excel(file_path, sheet_name)
    df["joinID"] = df[group]+df["quota_unit_final"]+df["source"]
    
    # determine QA df and merge:
    if(sheetName == "country"):
        df2 = trq_agg_origin
    elif(sheetName == "grouping"):
        df2 = trq_agg_grouping
        
    elif(sheetName == "region"):
        df2 = trq_agg_region
               
            
    df2["joinID"] = df2[group]+df2["quota_unit_final"]+df2["source"]
    df3 = pd.merge(df2,df[["total_quota_volume","total_quota_usage","total_allocation_fill_rate","joinID"]], on = "joinID", how = "left")
    
    # check df values:
    
    df3["volume_check"] = round(df3["quota_volume"],0)-round(df3["total_quota_volume"],0)
    df3["usage_check"] = round(df3["usage"],0)-round(df3["total_quota_usage"],0)
    df3["fill_rate_check"] = round(df3["fill_rate"],5)-round(df3["total_allocation_fill_rate"],5)
    
    print(df.shape,df2.shape)
    return(df3)

# %%
uk_trq_data_check("region","region")
# Out:
# (30, 8) (30, 8)
#                         region           quota_unit_final      quota_volume  \
# 0                       Africa                  Kilograms  1250952313.00000
# 1                       Africa                  Kilograms   314629400.00000
# 2                       Africa                     Litres   137756000.00000
# 3                       Africa                     Litres    72122600.00000
# 4                 Asia Pacific                  Kilograms  4049103800.09500
# 5                 Asia Pacific                  Kilograms   237435000.00000
# 6                 Asia Pacific          Square metre (m2)    17805290.00000
# 7                 Asia Pacific          Square metre (m2)     1068320.00000
# 8               Eastern Europe                  Kilograms 12285437042.75400
# 9               Eastern Europe                  Kilograms   904875906.00000
# 10              Eastern Europe                     Litres    60430000.00000
# 11              Eastern Europe                     Litres     8085726.30000
# 12                The Americas                  Kilograms  1763726000.00000
# 13                The Americas                  Kilograms   538510273.00000
# 14                The Americas  Litre pure (100%) alcohol     1435000.00000
# 15                The Americas  Litre pure (100%) alcohol      196400.00000
# 16                The Americas                     Litres       28000.00000
# 17                The Americas                     Litres        1700.00000
# 18                The Americas            Number of items   104926375.50000
# 19                The Americas            Number of items    23468686.00000
# 20                The Americas            Number of pairs    15362500.00000
# 21                The Americas            Number of pairs     2043000.00000
# 22                The Americas          Square metre (m2)    16191000.00000
# 23                The Americas          Square metre (m2)    13222000.00000
# 24  Wider Europe & Middle East                  Kilograms  2830630662.27500
# 25  Wider Europe & Middle East                  Kilograms   157551652.00000
# 26  Wider Europe & Middle East                     Litres    41484200.00000
# 27  Wider Europe & Middle East                     Litres      124600.00000
# 28  Wider Europe & Middle East            Number of items      129920.00000
# 29  Wider Europe & Middle East            Number of items       17942.00000
#
#               usage  fill_rate  quota_number source  \
# 0   701944589.51200    0.56113            58     EU
# 1   185740879.04000    0.59035            60     UK
# 2    96679497.62500    0.70182             4     EU
# 3    62438545.17600    0.86573             4     UK
# 4  1283041327.80100    0.31687            83     EU
# 5   110682361.00000    0.46616            46     UK
# 6     5876166.19700    0.33002             1     EU
# 7           0.00000    0.00000             1     UK
# 8  5599447746.73800    0.45578           190     EU
# 9   346090277.63300    0.38247           138     UK
# 10   46257038.47000    0.76546             9     EU
# 11     234283.80000    0.02897            11     UK
# 12  328407405.06800    0.18620           169     EU
# 13   71164672.66500    0.13215           237     UK
# 14    1045000.00000    0.72822             4     EU
# 15     136676.00000    0.69591             4     UK
# 16          0.00000    0.00000             1     EU
# 17          0.00000    0.00000             1     UK
# 18     203121.40000    0.00194            75     EU
# 19      55707.00000    0.00237           139     UK
# 20          0.00000    0.00000             6     EU
# 21          0.00000    0.00000             4     UK
# 22      10274.63900    0.00063             9     EU
# 23          0.00000    0.00000             8     UK
# 24  577313617.82200    0.20395           203     EU
# 25   21094225.21200    0.13389           153     UK
# 26   11210720.69300    0.27024             4     EU
# 27     121600.00000    0.97592             2     UK
# 28          0.00000    0.00000             1     EU
# 29          0.00000    0.00000             2     UK
#
#                                          joinID  total_quota_volume  \
# 0                             AfricaKilogramsEU    1250952313.00000
# 1                             AfricaKilogramsUK     314629400.00000
# 2                                AfricaLitresEU     137756000.00000
# 3                                AfricaLitresUK      72122600.00000
# 4                       Asia PacificKilogramsEU    4049103800.09500
# 5                       Asia PacificKilogramsUK     221394000.00000
# 6               Asia PacificSquare metre (m2)EU      17805290.00000
# 7               Asia PacificSquare metre (m2)UK       1068320.00000
# 8                     Eastern EuropeKilogramsEU   12285437042.75400
# 9                     Eastern EuropeKilogramsUK     759913906.00000
# 10                       Eastern EuropeLitresEU      60430000.00000
# 11                       Eastern EuropeLitresUK       7518256.75263
# 12                      The AmericasKilogramsEU    1763726000.00000
# 13                      The AmericasKilogramsUK     538510273.00000
# 14      The AmericasLitre pure (100%) alcoholEU       1435000.00000
# 15      The AmericasLitre pure (100%) alcoholUK        196400.00000
# 16                         The AmericasLitresEU         28000.00000
# 17                         The AmericasLitresUK          1700.00000
# 18                The AmericasNumber of itemsEU     104926375.50000
# 19                The AmericasNumber of itemsUK      23468686.00000
# 20                The AmericasNumber of pairsEU      15362500.00000
# 21                The AmericasNumber of pairsUK       2043000.00000
# 22              The AmericasSquare metre (m2)EU      16191000.00000
# 23              The AmericasSquare metre (m2)UK      13222000.00000
# 24        Wider Europe & Middle EastKilogramsEU    2830630662.27500
# 25        Wider Europe & Middle EastKilogramsUK     139569652.00000
# 26           Wider Europe & Middle EastLitresEU      41484200.00000
# 27           Wider Europe & Middle EastLitresUK        124600.00000
# 28  Wider Europe & Middle EastNumber of itemsEU        129920.00000
# 29  Wider Europe & Middle EastNumber of itemsUK         17942.00000
#
#     total_quota_usage  total_allocation_fill_rate    volume_check  \
# 0     701944589.51200                     0.56113         0.00000
# 1     186775277.74000                     0.59364         0.00000
# 2      96679497.62500                     0.70182         0.00000
# 3      62438545.17600                     0.86573         0.00000
# 4    1283041327.80100                     0.31687         0.00000
# 5     110682361.00000                     0.49993  16041000.00000
# 6       5876166.19700                     0.33002         0.00000
# 7             0.00000                     0.00000         0.00000
# 8    5599447746.73800                     0.45578         0.00000
# 9     314154947.63300                     0.41341 144962000.00000
# 10     46257038.47000                     0.76546         0.00000
# 11       234283.50003                     0.03116    567469.00000
# 12    328407405.06800                     0.18620         0.00000
# 13     71209672.66500                     0.13223         0.00000
# 14      1045000.00000                     0.72822         0.00000
# 15       136676.00000                     0.69591         0.00000
# 16            0.00000                     0.00000         0.00000
# 17            0.00000                     0.00000         0.00000
# 18       203121.40000                     0.00194         0.00000
# 19        55707.00000                     0.00237         0.00000
# 20            0.00000                     0.00000         0.00000
# 21            0.00000                     0.00000         0.00000
# 22        10274.63900                     0.00063         0.00000
# 23            0.00000                     0.00000         0.00000
# 24    577313617.82200                     0.20395         0.00000
# 25     21089725.21200                     0.15111  17982000.00000
# 26     11210720.69300                     0.27024         0.00000
# 27       121600.00000                     0.97592         0.00000
# 28            0.00000                     0.00000         0.00000
# 29            0.00000                     0.00000         0.00000
#
#       usage_check  fill_rate_check
# 0         0.00000          0.00000
# 1  -1034399.00000         -0.00330
# 2         0.00000          0.00000
# 3         0.00000          0.00000
# 4         0.00000          0.00000
# 5         0.00000         -0.03370
# 6         0.00000          0.00000
# 7         0.00000          0.00000
# 8         0.00000          0.00000
# 9  31935330.00000         -0.03090
# 10        0.00000          0.00000
# 11        0.00000         -0.00220
# 12        0.00000          0.00000
# 13   -45000.00000          0.00000
# 14        0.00000          0.00000
# 15        0.00000          0.00000
# 16        0.00000          0.00000
# 17        0.00000          0.00000
# 18        0.00000          0.00000
# 19        0.00000          0.00000
# 20        0.00000          0.00000
# 21        0.00000          0.00000
# 22        0.00000          0.00000
# 23        0.00000          0.00000
# 24        0.00000          0.00000
# 25     4500.00000         -0.01720
# 26        0.00000          0.00000
# 27        0.00000          0.00000
# 28        0.00000          0.00000
# 29        0.00000          0.00000

# %% [markdown]
# Function practice inserting one function into new one (so one function isn't excessivly large)

# %%
def return_diff_outputs(group):
    df = uk_trq_data_check(group,group)
    df = df.loc[(df["volume_check"] != 0) | (df["usage_check"] !=0) | (df["fill_rate_check"])]
    print(len(df), " mismatches between outputs and QA code for ",group, " type")
    return(df)

# %%
return_diff_outputs("grouping")
# Out:
# (90, 10) (91, 8)
# 12  mismatches between outputs and QA code for  grouping  type
#          grouping quota_unit_final    quota_volume           usage  fill_rate  \
# 29            EEA        Kilograms  35401383.00000   6762040.85900    0.19101
# 45          Japan        Kilograms   2958000.00000         0.00000    0.00000
# 55         Mexico        Kilograms 193965274.00000   5219659.40000    0.02691
# 59        Morocco        Kilograms 137583000.00000 100372342.84000    0.72954
# 67         Serbia           Litres    567526.30000         0.30000    0.00000
# 70  South Africa         Kilograms 297779500.00000 189836708.45000    0.63751
# 71  South Africa         Kilograms 118793000.00000  73539850.80000    0.61906
# 72  South Africa            Litres 114236000.00000  96663679.62500    0.84618
# 73  South Africa            Litres  71482900.00000  62438545.17600    0.87348
# 75    South Korea        Kilograms 190403000.00000  97511142.00000    0.51213
# 86         Turkey        Kilograms 446451000.00000 280871448.63300    0.62912
# 88        Ukraine        Kilograms 417412000.00000  65218829.00000    0.15625
#
#     quota_number source                    joinID  total_quota_volume  \
# 29            58     UK            EEAKilogramsUK      17419383.00000
# 45             2     UK          JapanKilogramsUK                 NaN
# 55            49     UK         MexicoKilogramsUK     193965274.00000
# 59            14     UK        MoroccoKilogramsUK     137583000.00000
# 67             2     UK            SerbiaLitresUK            56.75263
# 70            13     EU  South Africa KilogramsEU                 NaN
# 71            14     UK  South Africa KilogramsUK                 NaN
# 72             2     EU     South Africa LitresEU                 NaN
# 73             2     UK     South Africa LitresUK                 NaN
# 75            25     UK    South KoreaKilogramsUK     177320000.00000
# 86            64     UK         TurkeyKilogramsUK     348958000.00000
# 88            46     UK        UkraineKilogramsUK     369943000.00000
#
#     total_quota_usage  total_allocation_fill_rate   volume_check  \
# 29      6757540.85900                     0.38793 17982000.00000
# 45                NaN                         NaN            NaN
# 55      5264659.40000                     0.02714        0.00000
# 59    101406741.54000                     0.73706        0.00000
# 67            0.00003                     0.00000   567469.00000
# 70                NaN                         NaN            NaN
# 71                NaN                         NaN            NaN
# 72                NaN                         NaN            NaN
# 73                NaN                         NaN            NaN
# 75     97511142.00000                     0.54992 13083000.00000
# 86    248991938.63300                     0.71353 97493000.00000
# 88     65163009.00000                     0.17614 47469000.00000
#
#       usage_check  fill_rate_check
# 29     4500.00000         -0.19692
# 45            NaN              NaN
# 55   -45000.00000         -0.00023
# 59 -1034399.00000         -0.00752
# 67        0.00000          0.00000
# 70            NaN              NaN
# 71            NaN              NaN
# 72            NaN              NaN
# 73            NaN              NaN
# 75        0.00000         -0.03779
# 86 31879510.00000         -0.08441
# 88    55820.00000         -0.01989

# %%
trq_agg_grouping.loc[trq_agg_grouping["grouping"] == "South Africa "]
# Out:
#          grouping quota_unit_final    quota_volume           usage  fill_rate  \
# 35  South Africa         Kilograms 297779500.00000 189836708.45000    0.63751
# 35  South Africa         Kilograms 118793000.00000  73539850.80000    0.61906
# 36  South Africa            Litres 114236000.00000  96663679.62500    0.84618
# 36  South Africa            Litres  71482900.00000  62438545.17600    0.87348
#
#     quota_number source                    joinID
# 35            13     EU  South Africa KilogramsEU
# 35            14     UK  South Africa KilogramsUK
# 36             2     EU     South Africa LitresEU
# 36             2     UK     South Africa LitresUK

# %%
trq_agg_grouping["grouping"] = trq_agg_grouping["grouping"].str.strip()
#trq_agg_grouping["grouping2"] = trq_agg_grouping["grouping"].map(str).apply(lambda x: x.str.strip())

# %%
pd.unique(trq_agg_grouping["grouping"])
# Out:
# array(['Albania', 'Andean countries', 'Canada', 'Central America',
#        'Chile', 'EEA', 'Egypt', 'Faroe Islands', 'Georgia', 'Israel',
#        'Japan', 'Jordan', 'Kosovo', 'Lebanon', 'Mexico', 'Moldova',
#        'Morocco', 'North Macedonia', 'Serbia', 'Singapore',
#        'South Africa', 'South Korea', 'Switzerland', 'Tunisia', 'Turkey',
#        'Ukraine', 'Vietnam'], dtype=object)

# %%
trq_agg_origin2.head(50)
# Out:
#             region          grouping     quota_origin source  \
# 0           Africa             Egypt            Egypt     UK
# 1           Africa             Egypt            Egypt     EU
# 2           Africa           Morocco          Morocco     UK
# 3           Africa           Morocco          Morocco     EU
# 4           Africa      South Africa          Namibia     UK
# 5           Africa      South Africa     South Africa     UK
# 6           Africa      South Africa     South Africa     EU
# 7           Africa      South Africa     South Africa     UK
# 8           Africa      South Africa     South Africa     EU
# 9           Africa           Tunisia          Tunisia     UK
# 10          Africa           Tunisia          Tunisia     EU
# 11          Africa           Tunisia          Tunisia     UK
# 12          Africa           Tunisia          Tunisia     EU
# 13    Asia Pacific             Japan            Japan     EU
# 14    Asia Pacific         Singapore        Singapore     UK
# 15    Asia Pacific         Singapore        Singapore     EU
# 16    Asia Pacific       South Korea      South Korea     UK
# 17    Asia Pacific       South Korea      South Korea     EU
# 18    Asia Pacific       South Korea      South Korea     UK
# 19    Asia Pacific       South Korea      South Korea     EU
# 20    Asia Pacific           Vietnam          Vietnam     UK
# 21    Asia Pacific           Vietnam          Vietnam     EU
# 22  Eastern Europe           Albania          Albania     UK
# 23  Eastern Europe           Albania          Albania     EU
# 24  Eastern Europe           Albania          Albania     UK
# 25  Eastern Europe           Albania          Albania     EU
# 26  Eastern Europe           Georgia          Georgia     UK
# 27  Eastern Europe           Georgia          Georgia     EU
# 28  Eastern Europe            Kosovo           Kosovo     UK
# 29  Eastern Europe            Kosovo           Kosovo     EU
# 30  Eastern Europe            Kosovo           Kosovo     UK
# 31  Eastern Europe            Kosovo           Kosovo     EU
# 32  Eastern Europe           Moldova          Moldova     UK
# 33  Eastern Europe           Moldova          Moldova     EU
# 34  Eastern Europe   North Macedonia  North Macedonia     UK
# 35  Eastern Europe   North Macedonia  North Macedonia     EU
# 36  Eastern Europe   North Macedonia  North Macedonia     UK
# 37  Eastern Europe   North Macedonia  North Macedonia     EU
# 38  Eastern Europe            Serbia           Serbia     UK
# 39  Eastern Europe            Serbia           Serbia     EU
# 40  Eastern Europe            Serbia           Serbia     UK
# 41  Eastern Europe            Serbia           Serbia     EU
# 42  Eastern Europe            Turkey           Turkey     UK
# 43  Eastern Europe            Turkey           Turkey     EU
# 44  Eastern Europe           Ukraine          Ukraine     UK
# 45  Eastern Europe           Ukraine          Ukraine     EU
# 46    The Americas  Andean countries         Colombia     UK
# 47    The Americas  Andean countries         Colombia     EU
# 48    The Americas  Andean countries         Colombia     UK
# 49    The Americas  Andean countries         Colombia     EU
#
#              quota_unit_final  quota_count  total_quota_volume  \
# 0                   Kilograms           21      48638000.00000
# 1                   Kilograms           18     266715414.00000
# 2                   Kilograms           14     137583000.00000
# 3                   Kilograms           16     560158399.00000
# 4                   Kilograms            1        254000.00000
# 5                   Kilograms           13     118539000.00000
# 6                   Kilograms           13     297779500.00000
# 7                      Litres            2      71482900.00000
# 8                      Litres            2     114236000.00000
# 9                   Kilograms           11       9615400.00000
# 10                  Kilograms           11     126299000.00000
# 11                     Litres            2        639700.00000
# 12                     Litres            2      23520000.00000
# 13                  Kilograms           11      79779789.93000
# 14                  Kilograms            3        350000.00000
# 15                  Kilograms            3       1250000.00000
# 16                  Kilograms           19     177320000.00000
# 17                  Kilograms           52    3837159037.16500
# 18          Square metre (m2)            1       1068320.00000
# 19          Square metre (m2)            1      17805290.00000
# 20                  Kilograms           16      43724000.00000
# 21                  Kilograms           17     130914973.00000
# 22                  Kilograms            7        384000.00000
# 23                  Kilograms            7       2810000.00000
# 24                     Litres            3        163400.00000
# 25                     Litres            2        700000.00000
# 26                  Kilograms            1         30000.00000
# 27                  Kilograms            1        220000.00000
# 28                  Kilograms            3         70000.00000
# 29                  Kilograms            2         35000.00000
# 30                     Litres            3        749100.00000
# 31                     Litres            3       5000000.00000
# 32                  Kilograms            7      10789000.00000
# 33                  Kilograms           13     486186847.00000
# 34                  Kilograms            5       3893000.00000
# 35                  Kilograms           10     252309541.00000
# 36                     Litres            3       6605700.00000
# 37                     Litres            2      48000000.00000
# 38                  Kilograms            5      25846906.00000
# 39                  Kilograms           12     782138042.00000
# 40                     Litres            2            56.75263
# 41                     Litres            2       6730000.00000
# 42                  Kilograms           56     348958000.00000
# 43                  Kilograms           68    4045301876.00400
# 44                  Kilograms           42     369943000.00000
# 45                  Kilograms           77    6716435736.75000
# 46                  Kilograms           29      34239000.00000
# 47                  Kilograms           18     225020000.00000
# 48  Litre pure (100%) alcohol            1         19100.00000
# 49  Litre pure (100%) alcohol            1        220000.00000
#
#     total_quota_usage  total_allocation_fill_rate  iso
# 0      11783385.40000                     0.24227   EG
# 1      47602338.83200                     0.17848   EG
# 2     101406741.54000                     0.73706   MA
# 3     396049789.23000                     0.70703   MA
# 4             0.00000                     0.00000  NaN
# 5      73539850.80000                     0.62039   ZA
# 6     189836708.45000                     0.63751   ZA
# 7      62438545.17600                     0.87348   ZA
# 8      96663679.62500                     0.84618   ZA
# 9         45300.00000                     0.00471   TN
# 10     68455753.00000                     0.54201   TN
# 11            0.00000                     0.00000   TN
# 12        15818.00000                     0.00067   TN
# 13     16879143.64100                     0.21157   JP
# 14            0.00000                     0.00000   SG
# 15            0.00000                     0.00000   SG
# 16     97511142.00000                     0.54992   KR
# 17   1226434602.16000                     0.31962   KR
# 18            0.00000                     0.00000   KR
# 19      5876166.19700                     0.33002   KR
# 20     13171219.00000                     0.30124   VN
# 21     39727582.00000                     0.30346   VN
# 22            0.00000                     0.00000   AL
# 23      1673986.00000                     0.59572   AL
# 24            0.00000                     0.00000   AL
# 25         4038.00000                     0.00577   AL
# 26            0.00000                     0.00000   GE
# 27            0.00000                     0.00000   GE
# 28            0.00000                     0.00000   XK
# 29            0.00000                     0.00000   XK
# 30            0.00000                     0.00000   XK
# 31      3398564.50000                     0.67971   XK
# 32            0.00000                     0.00000   MD
# 33    157064088.96000                     0.32305   MD
# 34            0.00000                     0.00000   MK
# 35     71083442.00000                     0.28173   MK
# 36       234283.50000                     0.03547   MK
# 37     42197701.22000                     0.87912   MK
# 38            0.00000                     0.00000   RS
# 39    415418064.00000                     0.53113   RS
# 40            0.00003                     0.00000   RS
# 41       656734.75000                     0.09758   RS
# 42    248991938.63300                     0.71353   TR
# 43   1799497888.22100                     0.44484   TR
# 44     65163009.00000                     0.17614   UA
# 45   3154710277.55700                     0.46970   UA
# 46      2545398.46000                     0.07434   CO
# 47     75122899.14500                     0.33385   CO
# 48            0.00000                     0.00000   CO
# 49            0.00000                     0.00000   CO
